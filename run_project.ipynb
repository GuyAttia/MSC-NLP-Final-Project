# %% [markdown]
# # Imports

# %%
import sys
from google.colab import drive

# %% [markdown]
# # Install Requirements

# %%
drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive/M.Sc DS/Semesters/Semester 4/NLP/Final Project/Run Models/basic_features'
# !pip install -r requirements.txt
sys.path.append('/content/gdrive/MyDrive/M.Sc DS/Semesters/Semester 4/NLP/Final Project/Run Models/basic_features/src')

# %% [markdown]
# # Run Preprocessing

# %%
from src.data_processing import main as preprocessing_main

# %%
preprocessing_main()

# %% [markdown]
# # Run Model

# %%
from src.run_model import main as model_main

# %%
model_main(model='roberta_with_features')
